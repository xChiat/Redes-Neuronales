# %%
#Titanic Kaggle

# %%
import pandas as pd
datos = pd.read_csv("train.csv")

# %%
datos.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
datos.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import seaborn as sb
sb.countplot(x="Survived", data=datos)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sb.countplot(x="Survived", data=datos, hue="Sex")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
datos.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sb.displot(x="Age", data=datos)

# %%
datos["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
datos["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
datos["Age"].fillna(datos["Age"].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
datos["Age"] = datos["Age"].fillna(datos["Age"].mean())

# %%
datos["Age"]
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
datos.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
datos = datos.drop(["Cabin"], axis=1)

# %%
datos["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
datos = datos.dropna()

# %%
datos.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
datos = datos.drop(["Name", "PassengerId", "Ticket"], axis=1)

# %%
dummies_sex = pd.get_dummies(datos["Sex"], drop_first=True)

# %%
datos = datos.join(dummies_sex)
datos = datos.drop(["Sex"], axis=1)

# %%
sb.countplot(x="Survived", data=datos, hue="Embarked")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
dummies_embarked = pd.get_dummies(datos["Embarked"], drop_first=True)

# %%
datos = datos.join(dummies_embarked)
datos = datos.drop(["Embarked"], axis=1)

# %%
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sb.countplot(x="Survived", data=datos, hue="Pclass")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
X = datos.drop(["Survived"], axis=1)
y = datos["Survived"]

# %%
from sklearn.model_selection import train_test_split

X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size=.2)

# %%
from sklearn.tree import DecisionTreeClassifier

modelo = DecisionTreeClassifier(max_depth=10)
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.7921348314606742

# %%
from sklearn.tree import DecisionTreeClassifier

resultados = []
for i in range(1,15):
  modelo = DecisionTreeClassifier(max_depth=i)
  modelo.fit(X_ent, y_ent)
  predicciones = modelo.predict(X_pru)
  exactitud = accuracy_score(y_pru, predicciones)
  print(f"Resultado para {i}: {exactitud}")
  resultados.append(exactitud)
# Out:
# Resultado para 1: 0.7865168539325843
# Resultado para 2: 0.7696629213483146
# Resultado para 3: 0.8033707865168539
# Resultado para 4: 0.797752808988764
# Resultado para 5: 0.8033707865168539
# Resultado para 6: 0.8202247191011236
# Resultado para 7: 0.8089887640449438
# Resultado para 8: 0.797752808988764
# Resultado para 9: 0.8146067415730337
# Resultado para 10: 0.7808988764044944
# Resultado para 11: 0.7808988764044944
# Resultado para 12: 0.7640449438202247
# Resultado para 13: 0.7752808988764045
# Resultado para 14: 0.7752808988764045

# %%
sb.lineplot(data=resultados)
# Out:
# <Axes: >

# %%
modelo = DecisionTreeClassifier(max_depth=8)
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)
exactitud = accuracy_score(y_pru, predicciones)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       115
#            1       0.77      0.65      0.71        63
#
#     accuracy                           0.81       178
#    macro avg       0.80      0.77      0.78       178
# weighted avg       0.81      0.81      0.80       178

# %%
from sklearn.metrics import confusion_matrix
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index=["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       103        12
# Real: Si        22        41

# %%
X_ent.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'male', 'Q', 'S'], dtype='object')

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(100, 80))
plot_tree(
    modelo,
    feature_names=X_ent.columns,
    class_names=["Murió", "Vivió"],
    filled=True, label="none"
)
# Out:
# [Text(0.39881993006993005, 0.9444444444444444, 'male <= 0.5\n0.476\n711\n[434, 277]\nMurió'),
#  Text(0.21547202797202797, 0.8333333333333334, 'Pclass <= 2.5\n0.374\n249\n[62, 187]\nVivió'),
#  Text(0.307145979020979, 0.8888888888888888, 'True  '),
#  Text(0.07692307692307693, 0.7222222222222222, 'Age <= 2.5\n0.087\n132\n[6, 126]\nVivió'),
#  Text(0.04195804195804196, 0.6111111111111112, 'Parch <= 1.5\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.027972027972027972, 0.5, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.055944055944055944, 0.5, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.11188811188811189, 0.6111111111111112, 'Age <= 56.5\n0.074\n130\n[5, 125]\nVivió'),
#  Text(0.08391608391608392, 0.5, 'Age <= 27.5\n0.061\n127\n[4, 123]\nVivió'),
#  Text(0.06993006993006994, 0.3888888888888889, 'Age <= 24.5\n0.142\n52\n[4, 48]\nVivió'),
#  Text(0.04195804195804196, 0.2777777777777778, 'Fare <= 13.396\n0.044\n44\n[1, 43]\nVivió'),
#  Text(0.027972027972027972, 0.16666666666666666, 'Fare <= 12.5\n0.375\n4\n[1, 3]\nVivió'),
#  Text(0.013986013986013986, 0.05555555555555555, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.04195804195804196, 0.05555555555555555, '0.5\n2\n[1, 1]\nMurió'),
#  Text(0.055944055944055944, 0.16666666666666666, '0.0\n40\n[0, 40]\nVivió'),
#  Text(0.0979020979020979, 0.2777777777777778, 'SibSp <= 0.5\n0.469\n8\n[3, 5]\nVivió'),
#  Text(0.08391608391608392, 0.16666666666666666, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.11188811188811189, 0.16666666666666666, 'S <= 0.5\n0.48\n5\n[3, 2]\nMurió'),
#  Text(0.0979020979020979, 0.05555555555555555, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.1258741258741259, 0.05555555555555555, '0.375\n4\n[3, 1]\nMurió'),
#  Text(0.0979020979020979, 0.3888888888888889, '0.0\n75\n[0, 75]\nVivió'),
#  Text(0.13986013986013987, 0.5, 'Pclass <= 1.5\n0.444\n3\n[1, 2]\nVivió'),
#  Text(0.1258741258741259, 0.3888888888888889, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.15384615384615385, 0.3888888888888889, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.354020979020979, 0.7222222222222222, 'Fare <= 23.35\n0.499\n117\n[56.0, 61.0]\nVivió'),
#  Text(0.29545454545454547, 0.6111111111111112, 'Age <= 36.5\n0.472\n97\n[37, 60]\nVivió'),
#  Text(0.24825174825174826, 0.5, 'S <= 0.5\n0.452\n90\n[31, 59]\nVivió'),
#  Text(0.1958041958041958, 0.3888888888888889, 'Age <= 30.1\n0.386\n46\n[12, 34]\nVivió'),
#  Text(0.18181818181818182, 0.2777777777777778, 'Fare <= 15.373\n0.351\n44\n[10, 34]\nVivió'),
#  Text(0.16783216783216784, 0.16666666666666666, 'Fare <= 8.083\n0.415\n34\n[10, 24]\nVivió'),
#  Text(0.15384615384615385, 0.05555555555555555, '0.269\n25\n[4, 21]\nVivió'),
#  Text(0.18181818181818182, 0.05555555555555555, '0.444\n9\n[6, 3]\nMurió'),
#  Text(0.1958041958041958, 0.16666666666666666, '0.0\n10\n[0, 10]\nVivió'),
#  Text(0.2097902097902098, 0.2777777777777778, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.3006993006993007, 0.3888888888888889, 'Fare <= 10.798\n0.491\n44\n[19.0, 25.0]\nVivió'),
#  Text(0.2517482517482518, 0.2777777777777778, 'Fare <= 9.588\n0.493\n25\n[14.0, 11.0]\nMurió'),
#  Text(0.22377622377622378, 0.16666666666666666, 'SibSp <= 0.5\n0.499\n19\n[9, 10]\nVivió'),
#  Text(0.2097902097902098, 0.05555555555555555, '0.498\n17\n[9, 8]\nMurió'),
#  Text(0.23776223776223776, 0.05555555555555555, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.27972027972027974, 0.16666666666666666, 'Age <= 19.0\n0.278\n6\n[5, 1]\nMurió'),
#  Text(0.26573426573426573, 0.05555555555555555, '0.5\n2\n[1, 1]\nMurió'),
#  Text(0.2937062937062937, 0.05555555555555555, '0.0\n4\n[4, 0]\nMurió'),
#  Text(0.34965034965034963, 0.2777777777777778, 'SibSp <= 2.0\n0.388\n19\n[5, 14]\nVivió'),
#  Text(0.3356643356643357, 0.16666666666666666, 'Parch <= 0.5\n0.291\n17\n[3, 14]\nVivió'),
#  Text(0.32167832167832167, 0.05555555555555555, '0.444\n9\n[3, 6]\nVivió'),
#  Text(0.34965034965034963, 0.05555555555555555, '0.0\n8\n[0, 8]\nVivió'),
#  Text(0.36363636363636365, 0.16666666666666666, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.34265734265734266, 0.5, 'Age <= 55.0\n0.245\n7\n[6, 1]\nMurió'),
#  Text(0.32867132867132864, 0.3888888888888889, '0.0\n6\n[6, 0]\nMurió'),
#  Text(0.35664335664335667, 0.3888888888888889, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.4125874125874126, 0.6111111111111112, 'Age <= 7.0\n0.095\n20\n[19, 1]\nMurió'),
#  Text(0.3986013986013986, 0.5, 'Fare <= 31.331\n0.444\n3\n[2, 1]\nMurió'),
#  Text(0.38461538461538464, 0.3888888888888889, '0.0\n2\n[2, 0]\nMurió'),
#  Text(0.4125874125874126, 0.3888888888888889, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.42657342657342656, 0.5, '0.0\n17\n[17, 0]\nMurió'),
#  Text(0.5821678321678322, 0.8333333333333334, 'Age <= 3.5\n0.314\n462\n[372, 90]\nMurió'),
#  Text(0.49049388111888115, 0.8888888888888888, '  False'),
#  Text(0.45454545454545453, 0.7222222222222222, 'Fare <= 39.344\n0.142\n13\n[1, 12]\nVivió'),
#  Text(0.4405594405594406, 0.6111111111111112, '0.0\n11\n[0, 11]\nVivió'),
#  Text(0.46853146853146854, 0.6111111111111112, 'Pclass <= 2.0\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.45454545454545453, 0.5, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.4825174825174825, 0.5, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.7097902097902098, 0.7222222222222222, 'Pclass <= 1.5\n0.287\n449\n[371, 78]\nMurió'),
#  Text(0.5594405594405595, 0.6111111111111112, 'Age <= 53.0\n0.469\n101\n[63, 38]\nMurió'),
#  Text(0.5104895104895105, 0.5, 'Fare <= 26.144\n0.491\n83\n[47.0, 36.0]\nMurió'),
#  Text(0.4965034965034965, 0.3888888888888889, '0.0\n7\n[7, 0]\nMurió'),
#  Text(0.5244755244755245, 0.3888888888888889, 'Fare <= 27.135\n0.499\n76\n[40, 36]\nMurió'),
#  Text(0.4965034965034965, 0.2777777777777778, 'Age <= 32.35\n0.18\n10\n[1, 9]\nVivió'),
#  Text(0.4825174825174825, 0.16666666666666666, 'Age <= 28.85\n0.444\n3\n[1, 2]\nVivió'),
#  Text(0.46853146853146854, 0.05555555555555555, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.4965034965034965, 0.05555555555555555, '0.5\n2\n[1, 1]\nMurió'),
#  Text(0.5104895104895105, 0.16666666666666666, '0.0\n7\n[0, 7]\nVivió'),
#  Text(0.5524475524475524, 0.2777777777777778, 'Age <= 17.5\n0.483\n66\n[39, 27]\nMurió'),
#  Text(0.5384615384615384, 0.16666666666666666, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.5664335664335665, 0.16666666666666666, 'Fare <= 387.665\n0.472\n63\n[39, 24]\nMurió'),
#  Text(0.5524475524475524, 0.05555555555555555, '0.461\n61\n[39, 22]\nMurió'),
#  Text(0.5804195804195804, 0.05555555555555555, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.6083916083916084, 0.5, 'Age <= 75.5\n0.198\n18\n[16, 2]\nMurió'),
#  Text(0.5944055944055944, 0.3888888888888889, 'SibSp <= 0.5\n0.111\n17\n[16, 1]\nMurió'),
#  Text(0.5804195804195804, 0.2777777777777778, '0.0\n15\n[15, 0]\nMurió'),
#  Text(0.6083916083916084, 0.2777777777777778, 'S <= 0.5\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.5944055944055944, 0.16666666666666666, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.6223776223776224, 0.16666666666666666, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.6223776223776224, 0.3888888888888889, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.8601398601398601, 0.6111111111111112, 'Fare <= 51.698\n0.203\n348\n[308, 40]\nMurió'),
#  Text(0.7482517482517482, 0.5, 'Age <= 13.0\n0.191\n337\n[301, 36]\nMurió'),
#  Text(0.6783216783216783, 0.3888888888888889, 'SibSp <= 2.0\n0.444\n12\n[8, 4]\nMurió'),
#  Text(0.6643356643356644, 0.2777777777777778, 'Age <= 10.0\n0.32\n5\n[1, 4]\nVivió'),
#  Text(0.6503496503496503, 0.16666666666666666, '0.0\n3\n[0, 3]\nVivió'),
#  Text(0.6783216783216783, 0.16666666666666666, 'Age <= 11.5\n0.5\n2\n[1, 1]\nMurió'),
#  Text(0.6643356643356644, 0.05555555555555555, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.6923076923076923, 0.05555555555555555, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.6923076923076923, 0.2777777777777778, '0.0\n7\n[7, 0]\nMurió'),
#  Text(0.8181818181818182, 0.3888888888888889, 'S <= 0.5\n0.178\n325\n[293, 32]\nMurió'),
#  Text(0.7622377622377622, 0.2777777777777778, 'Age <= 29.35\n0.264\n64\n[54, 10]\nMurió'),
#  Text(0.7342657342657343, 0.16666666666666666, 'Fare <= 7.746\n0.444\n18\n[12, 6]\nMurió'),
#  Text(0.7202797202797203, 0.05555555555555555, '0.32\n10\n[8, 2]\nMurió'),
#  Text(0.7482517482517482, 0.05555555555555555, '0.5\n8\n[4, 4]\nMurió'),
#  Text(0.7902097902097902, 0.16666666666666666, 'SibSp <= 1.5\n0.159\n46\n[42, 4]\nMurió'),
#  Text(0.7762237762237763, 0.05555555555555555, '0.124\n45\n[42, 3]\nMurió'),
#  Text(0.8041958041958042, 0.05555555555555555, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.8741258741258742, 0.2777777777777778, 'Fare <= 13.25\n0.154\n261\n[239, 22]\nMurió'),
#  Text(0.8461538461538461, 0.16666666666666666, 'Fare <= 12.762\n0.182\n208\n[187, 21]\nMurió'),
#  Text(0.8321678321678322, 0.05555555555555555, '0.164\n189\n[172, 17]\nMurió'),
#  Text(0.8601398601398601, 0.05555555555555555, '0.332\n19\n[15, 4]\nMurió'),
#  Text(0.9020979020979021, 0.16666666666666666, 'Pclass <= 2.5\n0.037\n53\n[52, 1]\nMurió'),
#  Text(0.8881118881118881, 0.05555555555555555, '0.083\n23\n[22, 1]\nMurió'),
#  Text(0.916083916083916, 0.05555555555555555, '0.0\n30\n[30, 0]\nMurió'),
#  Text(0.972027972027972, 0.5, 'Fare <= 63.023\n0.463\n11\n[7, 4]\nMurió'),
#  Text(0.958041958041958, 0.3888888888888889, 'Age <= 30.85\n0.444\n6\n[2, 4]\nVivió'),
#  Text(0.9440559440559441, 0.2777777777777778, 'Age <= 27.0\n0.5\n4\n[2, 2]\nMurió'),
#  Text(0.9300699300699301, 0.16666666666666666, '0.0\n1\n[0, 1]\nVivió'),
#  Text(0.958041958041958, 0.16666666666666666, 'Age <= 28.85\n0.444\n3\n[2, 1]\nMurió'),
#  Text(0.9440559440559441, 0.05555555555555555, '0.0\n1\n[1, 0]\nMurió'),
#  Text(0.972027972027972, 0.05555555555555555, '0.5\n2\n[1, 1]\nMurió'),
#  Text(0.972027972027972, 0.2777777777777778, '0.0\n2\n[0, 2]\nVivió'),
#  Text(0.986013986013986, 0.3888888888888889, '0.0\n5\n[5, 0]\nMurió')]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pru, predicciones)
# Out:
# 0.8089887640449438

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       115
#            1       0.77      0.65      0.71        63
#
#     accuracy                           0.81       178
#    macro avg       0.80      0.77      0.78       178
# weighted avg       0.81      0.81      0.80       178

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_pru, predicciones)
# Out:
# array([[103,  12],
#        [ 22,  41]])

# %%
pd.DataFrame(confusion_matrix(y_pru, predicciones), columns=["Pred: No", "Pred: Si"], index=["Real: No", "Real: Si"])
# Out:
#           Pred: No  Pred: Si
# Real: No       103        12
# Real: Si        22        41

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare   male      Q      S
# 0       3  22.0      1      0   7.2500   True  False   True
# 1       1  38.0      1      0  71.2833  False  False  False
# 2       3  26.0      0      0   7.9250  False  False   True
# 3       1  35.0      1      0  53.1000  False  False   True
# 4       3  35.0      0      0   8.0500   True  False   True

# %%
nueva_persona = [2, 35, 0, 0, 80, 0, 0, 0]
prediccion = modelo.predict([nueva_persona])
if prediccion[0] == 1:
  print("Sobreviviste")
else:
  print("No sobreviviste")
# Out:
# Sobreviviste
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
